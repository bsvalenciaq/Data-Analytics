# %% [markdown]
#  # **Analitica de Datos - Taller**
#   **Brayan Valencia Quintero**

# %% [markdown]
# ## 1. Conceptos basicos en ciencia de datos y preprocesamiento

# %% [markdown]
# ### – Segun lo discutido en el material de apoyo ´ introduccion al aprendizaje de máquina ´ , discuta las principales ventajas y desventajas del aprendizaje estadístico vs. aprendizaje por reglas impuestas

# %% [markdown]
#  **Respuesta**: La principal ventaja del aprendizaje estadistico es que a partir de unos datos ingresados, se les hace mineria y se extrare la inormacion mas importante para crear las reglas que van a permitir predecir o tomar decisiones a partir de estos mismos datos, para una correcta prediccion es necesario tener una base de datos con una cantidad elevada de muestas, por lo que seria ideal para trabajos de big data. La desventaja es que necesita una gran cantidad de muestras para que sea mas efectivo, por lo que con una base de datos pequeña no va a dar el mejor resultado
#
# La desventaja del aprendizaje por reglas impuestas es que al momento de imponer las condiciones para su funcionamiento, este solo servira para ese fin programado, por ende si se le ingresan datos que no esperaba, generara un error.
# La ventaja se ve al momento de tratar con bases de datos con pocas muestras y en proyectos con poco presupuesto

# %% [markdown]
# ###– Cuales son las tareas básicas del aprendizaje de máquina?. Realice un cuadro comparativo indicando el dominio y rango de la funcion de aprendizaje a encontrar en cada caso

# %% [markdown]
# ![Analitica1.jpg](data:image/jpeg;base64,...)
#
#
#
# ![analitica2.png](data:image/png;base64,...)

# %% [markdown]
# ### – Consultar y realizar los ejercicios propuestos en el cuaderno de Colab Introduccion a Numpy .

# %% [markdown]
# https://colab.research.google.com/drive/1W88yYT7Ueq6gSJh_0azKuB8V1p0HwkzN?authuser=1

# %% [markdown]
# ## 2.  Aprendizaje de maquina en tareas de regresion

# %% [markdown]
# ### - Consultar y realizar los ejercicios propuestos en el cuaderno de Colab Guıa lado a lado en aprendizaje de maquina.

# %% [markdown]
# https://colab.research.google.com/drive/1YAj6DDFGbyZZQNdEL0KyzdXJm1SKFiZm?authuser=1#scrollTo=9270xelJg8e6&uniqifier=2

# %% [markdown]
# ### – Consultar y realizar los ejercicios propuestos en el cuaderno de Colab Regresion no lineal y busqueda de hiperparametros.

# %% [markdown]
# https://colab.research.google.com/drive/1MnYVJaILI1NL97dG6F5Idw5LITW43fst?authuser=1

# %% [markdown]
# ### – Consultar y realizar los ejercicios propuestos en el cuaderno de Colab Comparacion métodos de regresión

# %% [markdown]
# https://colab.research.google.com/drive/1Y3nqn1vLUVToyTVGQKQyb45dOUqy-Rdk?a

# %% [markdown]
# ## 3. Anteproyecto - aplicacion en analıtica de datos

# %% [markdown]
# ### – Escoger una base de datos de al menos 1000 instancias y 100 atributos, relacionada con alguna de las tareas basicas en aprendizaje de maquina (clasificación, regresıon o conglomerados). Se sugiere revisar los repositorios Kaggle, UCI machine learning, y Google Dataset search.

# %% [markdown]
# La base de datos escogida para el proyecto se llama "music genre classification", esta base tiene 2001 filas y 120 columnas.
#
# https://www.kaggle.com/andradaolteanu/gtzan-dataset-music-genre-classification

# %% [markdown]
# ### – Realice una analisis exploratorio utilizando Pandas de los atributos y la salida de la base de datos (histogramas, boxplot, matriz de correlacion de Pearson, scatter matrix). Discuta las relaciones encontradas entre las entradas, y entre las entradas y la salida.

# %% [markdown]
# https://colab.research.google.com/drive/11av6QgeKtPP5OlXDwbDx67qXAKuXaWEl?authuser=1
#
# Al realizar el analisis exploratorio de esta base de datos, se pudo observar que no tiene espacios vacios lo cual es una buena noticia, debito a que gracias a esto no hay necesidad de completar espacios vacios.
# En los atributos de la base de datos, se puede detallar que tiene un atributo tipo objeto llamado "filename" que hace referencia al nombre de cada genero, sera necesario aplicar agrupacion para agrupar todas las muestras de cada genero. Hay un atributo tipo entero y el resto de atributos son flotantes.
#
# Observando los histogramas nos podemos dar cuenta que los datos son simetricos

# %% [markdown]
# ### – Realizar un estudio del estado del arte, de al menos 3 artıculos cientıficos (papers) de los ultimos cuatro años, relacionados con la base de datos escogida, describiendo potenciales aplicaciones, desafıos en el preprocesamiento, tipos de algoritmos de aprendizaje de maquina utilizados, metricas dde desempeno, etc. Consulte en revistas Q1/Q2 (utilizar el buscador de revistas de Scimago journal ranking para corroborar la categorıa de la revista). Se sugiere utilizar el buscador de bases de datos de la UNAL y Google scholar para encontrar artıculos cientıficos relevantes.

# %% [markdown]
# La base de datos a utilizar en el proyecto contiene archivos de audio,se busca desarrollar un clasificador de generos musicales.
# Realizando el estudio de los articulos notamos que usan algoritmos parecidos, entre los usados estan:
#  CNN(Convolutional Neural Networks)"La cual es un tipo de Red Neuronal Artificial con aprendizaje supervisado que procesa sus capas imitando al cortex visual del ojo humano para identificar distintas características en las entradas que en definitiva hacen que pueda identificar objetos y “ver”. Para ello, la CNN contiene varias capas ocultas especializadas".
#   KNN(K-Nearest-Neighbor) "el cual es un algoritmo basado en instancia de tipo supervisado. Puede usarse para clasificar nuevas muestras o para predecir. Sirve esencialmente para clasificar valores buscando los puntos de datos “más similares” (por cercanía) aprendidos en la etapa de entrenamiento y haciendo conjeturas de nuevos puntos basado en esa clasificación", RNN(Recurrent neural network)las cuales "son un algoritmo  para datos secuenciales, es utilizada por Siri de Apple y la búsqueda por voz de Google. Es un algoritmo que recuerda su entrada, debido a una memoria interna, lo que lo hace perfectamente adecuado para problemas de aprendizaje automático que involucran datos secuenciales.
#
# Por ahora podemos concluir que el algoritmo que tiene mejor porcentaje de acierto es el que utiliza un paralelo entre CNN y RNN, el cual fue usado en el articulo numero 2, por lo cual consideramos apropiado tratar de implementarlo en el proyecto
#
#
#
#  Articulos#
#
# 1.Neural Network Music Genre Classification
#
#
# https://ieeexplore-ieee-org.ezproxy.unal.edu.co/document/9165253
#
# 2.Parallel Recurrent Convolutional Neural Networks-Based Music Genre Classification Method for Mobile Devices
# https://ieeexplore.ieee.org/abstract/document/8964009
#
# 3.Parallel Deep Neural Networks for Musical Genre Classification: A Case Study
# https://ieeexplore-ieee-org.ezproxy.unal.edu.co/document/9529756
#
#
# 4.utomatic Music Genre Classification Based on Linguistic Frequencies Using Machine Learning
#
# https://ieeexplore-ieee-org.ezproxy.unal.edu.co/document/9585937
